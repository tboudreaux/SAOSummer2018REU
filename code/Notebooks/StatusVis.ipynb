# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../../simulations/externalSimulations/oldSimulations/runTests/MultiBinaryTest/Binary0-0/Binary0-0/status.36', sep=r'\s+', engine='python')

# %%
df.T
# Out:
#                          0            1            2            3    \
# 0.00000000           0.03125       0.0625        0.125         0.25
# 0.00000000.1       0.0172547    0.0345094    0.0690188     0.138038
# 1.56170869        0.00149191  0.000556867   0.00018599  5.03858e-05
# 8.14003849           6948.92      18800.3      57599.9       225655
# 593.225708           593.226      593.226      593.226      593.225
# 593.225708.1         266.822      266.822       268.11       268.11
# 0.00000000.2         326.403      326.403      325.116      325.116
# 0.500000119       0.00911922   0.00478863   0.00232373   0.00098178
# 0.755239129          0.75155      0.75401     0.759817     0.775037
# Infinity            Infinity     Infinity     Infinity     Infinity
# 4.70978856E-09  -8.72881e-09 -1.20822e-08 -1.36169e-07 -1.22666e-06
# 4.74746686E-09  -1.26599e-08  -1.8588e-09  2.56997e-09  3.16052e-07
# -2.49932786E-09  3.41087e-08  1.55117e-07  5.71794e-07  1.80447e-06
# ...

# %%
time = df.iloc[:, 1]
mass = df.iloc[:, 9]

# %%
plt.plot(time, mass)
