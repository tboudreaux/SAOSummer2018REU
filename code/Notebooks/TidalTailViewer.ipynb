# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import MultipleLocator
from matplotlib.ticker import AutoMinorLocator
import h5py


plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %matplotlib inline

# %%
PATH = "../../simulations/runTests/ExternalPotentialTest2/N1k_R3_K_xtern/snap.40_1304.h5part"

# %%
f = h5py.File(PATH)

# %%
step = 15
x = f[f'Step#{step}']['X1']
y = f[f'Step#{step}']['X2']
z = f[f'Step#{step}']['X3']

print(x)
# Out:
# <HDF5 dataset "X1": shape (990,), type "<f4">

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, 'ko', linewidth=1, markersize=1)

ax.set_xlabel('X [ly]', fontsize=20, labelpad=15)
ax.set_ylabel('Y [ly]', fontsize=20, labelpad=15)
ax.set_zlabel('Z [ly]', fontsize=20)

ax.tick_params(axis='both', which='major', labelsize=15, length=12, direction='in')
ax.tick_params(axis='both', which='minor', length=6, direction='in')

# ax.view_init(90, 270)

# filename = "{}_{}.pdf".format(base_filename, 'XYZ')
# plt.savefig('Figures/PaperFigures/{}'.format(filename), bbox_inches='tight')

# %%
list(f['Step#13'])
# Out:
# ['Binaries',
#  'KW',
#  'L',
#  'M',
#  'MC',
#  'NAM',
#  'POT',
#  'RC',
#  'RS',
#  'TE',
#  'V1',
#  'V2',
#  'V3',
#  'X1',
#  'X2',
#  'X3']
